# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
#!pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Data Transformations
#
# We first start with defining our data transformations. We need to think what our data is and how can we augment it to correct represent images which it might not see otherwise.

# %%
# Train Phase transformations
train_transforms = transforms.Compose([
                                       #transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                       #transforms.RandomAffine(degrees=20, translate=(0.1,0.1), scale=(0.9, 1.1)),
                                       #transforms.RandomRotation((-7.0, 7.0), fill=(1,)),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # The mean and std have to be sequences (e.g., tuples), therefore you should add a comma after the values.
                                       ])

# Test Phase transformations
test_transforms = transforms.Compose([
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                       ])

# %% [markdown]
# # Dataset and Creating Train/Test Split

# %%
train = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transforms)
test = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transforms)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49777649.20it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# # Dataloader Arguments & Test/Train Dataloaders

# %%
SEED = 1
BATCH_SIZE = 128
# CUDA?
cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)

# For reproducibility
torch.manual_seed(SEED)

if cuda:
    torch.cuda.manual_seed(SEED)

# train dataloader
train_loader = torch.utils.data.DataLoader(train, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

# test dataloader
test_loader = torch.utils.data.DataLoader(test, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
# Out:
# CUDA Available? False

# %%
print(len(train_loader))
print(len(test_loader))
# Out:
# 391
# 79

# %%
for batch in train_loader:
       print(batch[0].shape)
       break
# Out:
# torch.Size([128, 3, 32, 32])

# %%
for batch in train_loader:
       print(batch[1].shape)
       break
# Out:
# torch.Size([128])

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(BATCH_SIZE)))
# Out:
#  bird   cat truck   car   cat horse truck   cat  deer horse   cat plane truck truck   cat   cat   car horse  bird  ship   cat  bird truck horse  frog  ship  ship   dog   dog   dog   car  frog  frog horse   cat truck horse  deer  ship  deer  frog plane  deer plane  frog  bird  ship  ship plane  frog  deer   dog  ship  ship   dog  deer   cat horse  bird  bird  deer   car  deer horse truck plane horse plane   dog plane plane horse   cat   dog truck plane  deer truck horse horse truck truck  frog   car truck plane  bird  ship   cat   car  frog   cat  bird   dog  ship   dog  bird horse  ship   cat   dog horse horse truck truck plane truck truck horse  deer  frog  frog  ship   cat   car   car plane truck  bird   car  deer   car  ship   car  deer  frog   car horse

# %% [markdown]
# # The model
# Let's start with the model we first saw

# %%
# importing the model from the model.py

import model
from model import NetGroupNormalization

model = NetGroupNormalization().to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 30, 30]             432
#          GroupNorm-2           [-1, 16, 30, 30]              32
#               ReLU-3           [-1, 16, 30, 30]               0
#             Conv2d-4           [-1, 16, 28, 28]           2,304
#               ReLU-5           [-1, 16, 28, 28]               0
#             Conv2d-6           [-1, 16, 30, 30]             256
#          GroupNorm-7           [-1, 16, 30, 30]              32
#               ReLU-8           [-1, 16, 30, 30]               0
#          MaxPool2d-9           [-1, 16, 15, 15]               0
#            Conv2d-10           [-1, 16, 13, 13]           2,304
#         GroupNorm-11           [-1, 16, 13, 13]              32
#              ReLU-12           [-1, 16, 13, 13]               0
#            Conv2d-13           [-1, 16, 11, 11]           2,304
#         GroupNorm-14           [-1, 16, 11, 11]              32
#              ReLU-15           [-1, 16, 11, 11]               0
#            Conv2d-16             [-1, 32, 9, 9]           4,608
#         GroupNorm-17             [-1, 32, 9, 9]              64
#              ReLU-18             [-1, 32, 9, 9]               0
#            Conv2d-19           [-1, 32, 11, 11]           1,024
#         GroupNorm-20           [-1, 32, 11, 11]              64
#              ReLU-21           [-1, 32, 11, 11]               0
#         MaxPool2d-22             [-1, 32, 5, 5]               0
#            Conv2d-23             [-1, 32, 3, 3]           9,216
#         GroupNorm-24             [-1, 32, 3, 3]              64
#              ReLU-25             [-1, 32, 3, 3]               0
#            Conv2d-26             [-1, 32, 3, 3]           9,216
#         GroupNorm-27             [-1, 32, 3, 3]              64
#              ReLU-28             [-1, 32, 3, 3]               0
#            Conv2d-29             [-1, 10, 3, 3]           2,880
#         AvgPool2d-30             [-1, 10, 1, 1]               0
#            Conv2d-31             [-1, 10, 1, 1]             100
# ================================================================
# Total params: 35,028
# Trainable params: 35,028
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.15
# Params size (MB): 0.13
# Estimated Total Size (MB): 1.30
# ----------------------------------------------------------------

# %% [markdown]
# # Training and Testing

# %%
# Function fopr Training the model of the train dataset.
from tqdm import tqdm
train_losses = []
test_losses = []
train_acc = []
test_acc = []
def GetCorrectPredCount(pPrediction, pLabels):
  return pPrediction.argmax(dim=1).eq(pLabels).sum().item()


def train(model, device, train_loader, optimizer, epoch):
    model.train()
    pbar = tqdm(train_loader)

    train_loss = 0
    correct = 0
    processed = 0

    for batch_idx, (data, target) in enumerate(pbar):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        # Predict
        output = model(data)

        # Calculate loss
        loss = F.nll_loss(output, target)
        train_loss+=loss.item()

        # Backpropagation
        loss.backward()
        optimizer.step()

        correct += GetCorrectPredCount(output, target)
        processed += len(data)
        #pbar.set_description(desc= f'loss={loss.item()} batch_id={batch_idx}')
        pbar.set_description(desc= f'Train: Loss={loss.item():0.4f} Batch_id={batch_idx} Accuracy={100*correct/processed:0.2f}')


    train_acc.append(100*correct/processed)
    train_losses.append(train_loss/len(train_loader))

# Testing the trained model on test dataset to the check loss and model accuracy
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_acc.append(100. * correct / len(test_loader.dataset))
    test_losses.append(test_loss)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# # Let's Train and test our model

# %%
train_losses = []
test_losses = []
train_acc = []
test_acc = []

model =  NetGroupNormalization().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

EPOCHS = 20
for epoch in range(EPOCHS):
    print("EPOCH:", epoch+1)
    train(model, device, train_loader, optimizer, epoch)

    test(model, device, test_loader)
# Out:
# EPOCH: 1
# Train: Loss=1.5930 Batch_id=390 Accuracy=30.31: 100%|██████████| 391/391 [01:25<00:00,  4.58it/s]
# Test set: Average loss: 1.6052, Accuracy: 4109/10000 (41.09%)
#
# EPOCH: 2
# Train: Loss=1.4373 Batch_id=390 Accuracy=45.96: 100%|██████████| 391/391 [01:24<00:00,  4.61it/s]
# Test set: Average loss: 1.4257, Accuracy: 4872/10000 (48.72%)
#
# EPOCH: 3
# Train: Loss=1.1581 Batch_id=390 Accuracy=52.03: 100%|██████████| 391/391 [01:28<00:00,  4.42it/s]
# Test set: Average loss: 1.2661, Accuracy: 5454/10000 (54.54%)
#
# EPOCH: 4
# Train: Loss=1.2549 Batch_id=390 Accuracy=56.80: 100%|██████████| 391/391 [01:28<00:00,  4.43it/s]
# Test set: Average loss: 1.1767, Accuracy: 5781/10000 (57.81%)
#
# EPOCH: 5
# Train: Loss=0.9609 Batch_id=390 Accuracy=60.35: 100%|██████████| 391/391 [01:28<00:00,  4.43it/s]
# Test set: Average loss: 1.0849, Accuracy: 6161/10000 (61.61%)
#
# EPOCH: 6
# Train: Loss=1.0292 Batch_id=390 Accuracy=62.32: 100%|██████████| 391/391 [01:28<00:00,  4.42it/s]
# Test set: Average loss: 1.0908, Accuracy: 6169/10000 (61.69%)
#
# EPOCH: 7
# Train: Loss=1.2436 Batch_id=390 Accuracy=64.67: 100%|██████████| 391/391 [01:27<00:00,  4.45it/s]
# Test set: Average loss: 1.0307, Accuracy: 6418/10000 (64.18%)
#
# EPOCH: 8
# Train: Loss=0.7895 Batch_id=390 Accuracy=66.17: 100%|██████████| 391/391 [01:26<00:00,  4.50it/s]
# Test set: Average loss: 0.9756, Accuracy: 6586/10000 (65.86%)
#
# EPOCH: 9
# Train: Loss=0.7883 Batch_id=390 Accuracy=68.18: 100%|██████████| 391/391 [01:32<00:00,  4.22it/s]
# Test set: Average loss: 0.9523, Accuracy: 6637/10000 (66.37%)
#
# EPOCH: 10
# Train: Loss=1.0394 Batch_id=390 Accuracy=68.85: 100%|██████████| 391/391 [01:28<00:00,  4.41it/s]
# Test set: Average loss: 0.9480, Accuracy: 6684/10000 (66.84%)
#
# EPOCH: 11
# Train: Loss=0.9427 Batch_id=390 Accuracy=70.29: 100%|██████████| 391/391 [01:29<00:00,  4.39it/s]
# Test set: Average loss: 0.9360, Accuracy: 6732/10000 (67.32%)
#
# EPOCH: 12
# Train: Loss=0.7837 Batch_id=390 Accuracy=71.16: 100%|██████████| 391/391 [01:26<00:00,  4.50it/s]
# Test set: Average loss: 0.8710, Accuracy: 6959/10000 (69.59%)
#
# EPOCH: 13
# Train: Loss=0.8925 Batch_id=390 Accuracy=71.79: 100%|██████████| 391/391 [01:27<00:00,  4.45it/s]
# Test set: Average loss: 0.8711, Accuracy: 6967/10000 (69.67%)
#
# EPOCH: 14
# Train: Loss=0.9811 Batch_id=390 Accuracy=72.68: 100%|██████████| 391/391 [01:28<00:00,  4.42it/s]
# Test set: Average loss: 0.9138, Accuracy: 6828/10000 (68.28%)
#
# EPOCH: 15
# Train: Loss=0.7601 Batch_id=390 Accuracy=73.36: 100%|██████████| 391/391 [01:28<00:00,  4.43it/s]
# Test set: Average loss: 0.8433, Accuracy: 7067/10000 (70.67%)
#
# EPOCH: 16
# Train: Loss=0.8097 Batch_id=390 Accuracy=73.92: 100%|██████████| 391/391 [01:26<00:00,  4.52it/s]
# Test set: Average loss: 0.8573, Accuracy: 7052/10000 (70.52%)
#
# EPOCH: 17
# Train: Loss=0.7422 Batch_id=390 Accuracy=73.98: 100%|██████████| 391/391 [01:27<00:00,  4.47it/s]
# Test set: Average loss: 0.8171, Accuracy: 7149/10000 (71.49%)
#
# EPOCH: 18
# Train: Loss=0.8735 Batch_id=390 Accuracy=75.27: 100%|██████████| 391/391 [01:27<00:00,  4.45it/s]
# Test set: Average loss: 0.8676, Accuracy: 6982/10000 (69.82%)
#
# EPOCH: 19
# Train: Loss=0.9085 Batch_id=390 Accuracy=75.48: 100%|██████████| 391/391 [01:28<00:00,  4.41it/s]
# Test set: Average loss: 0.9383, Accuracy: 6895/10000 (68.95%)
#
# EPOCH: 20
# Train: Loss=0.6756 Batch_id=390 Accuracy=76.18: 100%|██████████| 391/391 [01:29<00:00,  4.37it/s]
# Test set: Average loss: 0.8182, Accuracy: 7122/10000 (71.22%)

# %%
#!pip install utils
# Display the loss and accuracy in tranining and Test Data.
import utils
from utils import display_plot

display_plot(train_losses,train_acc,test_losses,test_acc)

# %%
# Check the Test Data Set

dataiter = iter(test_loader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(BATCH_SIZE)))
# Out:
# GroundTruth:    cat  ship  ship plane  frog  frog   car  frog   cat   car plane truck   dog horse truck  ship   dog horse  ship  frog horse plane  deer truck   dog  bird  deer plane truck  frog  frog   dog  deer   dog truck  bird  deer   car truck   dog  deer  frog   dog  frog plane truck   cat truck horse  frog truck  ship plane   cat  ship  ship horse horse  deer  frog horse   cat  frog   cat  frog  bird   car  bird   cat horse  bird  frog  ship  ship plane  bird truck   cat   cat  ship  ship   car   car horse  bird   dog  bird horse  ship truck plane   cat  ship  frog  deer  frog  frog plane plane horse  deer   dog  frog   cat   car   car   cat  frog  ship horse  deer plane  frog  bird   car   cat plane  deer  bird horse  ship   cat   car  bird  ship plane  ship   cat

# %%
# Check the Prediction as classes that performed well, and the classes that did not perform well:


use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
model = NetGroupNormalization().to(device)
model.eval()
with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        outputs = model(data)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == target).squeeze()
        for i in range(4):
            label = target[i].to(device)
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# cpu
# Accuracy of plane :  0 %
# Accuracy of   car :  0 %
# Accuracy of  bird : 100 %
# Accuracy of   cat :  0 %
# Accuracy of  deer :  0 %
# Accuracy of   dog :  0 %
# Accuracy of  frog :  0 %
# Accuracy of horse :  0 %
# Accuracy of  ship :  0 %
# Accuracy of truck :  0 %

# %%
from utils import convert_to_imshow_format

# %%
# Shows the images in first batch of the test_loader 128 images, in 1*128 format with label
dataiter = iter(test_loader)
images, labels = next(dataiter)

#print(len(images))


#model = Net().to(device)
model = NetGroupNormalization()
model.eval()

incorrect_pred = []

for idx,p in enumerate(predicted):
  #print("index --- ",idx)
  #print("predicted ---",classes[p])
  #print("Target ---",classes[labels[idx]])
  #print("Compare", classes[p] != classes[labels[idx]])
  if classes[p] != classes[labels[idx]]:

  #if p != labels[idx]:
    incorrect_pred.append(idx)
  #print(incorrect_pred)

index = 0
# show only the first 10 images in 2,5 format
fig, axes = plt.subplots(2, 5, figsize=(12,5))
plt.subplots_adjust(bottom=2.3, top=2.7, hspace=1)
#for idx, image in enumerate(images):
for p in range(0,2):
  for q in range(0,5):
    #print(idx)

    if index >= 10:
      break
    index=index+1
    #print(image.type)
    axes[p,q].imshow(convert_to_imshow_format(images[incorrect_pred[index]]))
    axes[p,q].set_title('Target - ' + classes[labels[incorrect_pred[index]]]+'\n'+'Predicted - '+ classes[predicted[incorrect_pred[index]]],fontsize = 8)
    axes[p,q].set_xticks([])
    axes[p,q].set_yticks([])

# %% [markdown]
# ## Model 3
#
# Results:
#
# *   Parameters: Total params: 34,644
# *   Train: (74.84)%
# *   Test set: (70.99%)
# *   EPOCH : 20
#
#
# *   Analysis:
# 1. Model is underfitting.
# 2. The accuracy has reached the 70.99% with the Layer Normalization.
